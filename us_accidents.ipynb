# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import datetime 
import calendar

# %%
# Reading a csv file
file_raw = pd.read_csv('US_Accidents_June20.csv')

# %%
file_raw
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 3513612  A-3513776      Bing    NaN         2  2019-08-23 18:03:25
# 3513613  A-3513777      Bing    NaN         2  2019-08-23 19:11:30
# 3513614  A-3513778      Bing    NaN         2  2019-08-23 19:00:21
# 3513615  A-3513779      Bing    NaN         2  2019-08-23 19:00:21
# 3513616  A-3513780      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...

# %%
file_raw.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
file_raw.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# ...

# %%
# pd.to_datetime(df['I_DATE'])
# df['I_DATE'].dt.date
# df['I_DATE'].dt.time
# updated_df = df.astype({'timestamp':'datetime64[ns]'})

# %%
# object type to date type
file_raw_dates = file_raw.astype({'Start_Time':'datetime64[ns]'})

# %%
# splitting datetime to date and time
file_raw_dates['start_date'] = file_raw_dates['Start_Time'].dt.date
file_raw_dates['start_time'] = file_raw_dates['Start_Time'].dt.time
file_raw_dates.dtypes
# Out:
# ID                               object
# Source                           object
# TMC                             float64
# Severity                          int64
# Start_Time               datetime64[ns]
# End_Time                         object
# Start_Lat                       float64
# Start_Lng                       float64
# End_Lat                         float64
# End_Lng                         float64
# Distance(mi)                    float64
# Description                      object
# Number                          float64
# Street                           object
# Side                             object
# City                             object
# County                           object
# State                            object
# Zipcode                          object
# Country                          object
# Timezone                         object
# Airport_Code                     object
# Weather_Timestamp                object
# ...

# %%
# changing column order
file_dates = file_raw_dates[['ID', 'Source', 'TMC', 'Severity', 'Start_Time','start_date', 'start_time', 'End_Time',
       'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
       'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
       'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
       'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
       'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
       'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
       'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
       'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
       'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
       'Astronomical_Twilight']].astype({'start_date':'datetime64[ns]'})

# %%
file_dates
# Out:
#                 ID    Source    TMC  Severity          Start_Time start_date  \
# 0              A-1  MapQuest  201.0         3 2016-02-08 05:46:00 2016-02-08
# 1              A-2  MapQuest  201.0         2 2016-02-08 06:07:59 2016-02-08
# 2              A-3  MapQuest  201.0         2 2016-02-08 06:49:27 2016-02-08
# 3              A-4  MapQuest  201.0         3 2016-02-08 07:23:34 2016-02-08
# 4              A-5  MapQuest  201.0         2 2016-02-08 07:39:07 2016-02-08
# ...            ...       ...    ...       ...                 ...        ...
# 3513612  A-3513776      Bing    NaN         2 2019-08-23 18:03:25 2019-08-23
# 3513613  A-3513777      Bing    NaN         2 2019-08-23 19:11:30 2019-08-23
# 3513614  A-3513778      Bing    NaN         2 2019-08-23 19:00:21 2019-08-23
# 3513615  A-3513779      Bing    NaN         2 2019-08-23 19:00:21 2019-08-23
# 3513616  A-3513780      Bing    NaN         2 2019-08-23 18:52:06 2019-08-23
#
# ...

# %%
file_dates.dtypes
# Out:
# ID                               object
# Source                           object
# TMC                             float64
# Severity                          int64
# Start_Time               datetime64[ns]
# start_date               datetime64[ns]
# start_time                       object
# End_Time                         object
# Start_Lat                       float64
# Start_Lng                       float64
# End_Lat                         float64
# End_Lng                         float64
# Distance(mi)                    float64
# Description                      object
# Number                          float64
# Street                           object
# Side                             object
# City                             object
# County                           object
# State                            object
# Zipcode                          object
# Country                          object
# Timezone                         object
# ...

# %%
# extracting weekday from dates - example
def findDay(date): 
    born = datetime.datetime.strptime(date, '%Y-%m-%d').weekday() 
    return (calendar.day_name[born]) 
  
# Driver program 
date = '2020-12-24'
print(findDay(date))
# Out:
# Thursday

# %%
file_dates['start_date']
# Out:
# 0         2016-02-08
# 1         2016-02-08
# 2         2016-02-08
# 3         2016-02-08
# 4         2016-02-08
#              ...
# 3513612   2019-08-23
# 3513613   2019-08-23
# 3513614   2019-08-23
# 3513615   2019-08-23
# 3513616   2019-08-23
# Name: start_date, Length: 3513617, dtype: datetime64[ns]

# %%
file_dates['weekday'] = file_dates['start_date'].apply(lambda x: calendar.day_name[x.weekday()])

# %%
file_dates
# Out:
#                 ID    Source    TMC  Severity          Start_Time start_date  \
# 0              A-1  MapQuest  201.0         3 2016-02-08 05:46:00 2016-02-08
# 1              A-2  MapQuest  201.0         2 2016-02-08 06:07:59 2016-02-08
# 2              A-3  MapQuest  201.0         2 2016-02-08 06:49:27 2016-02-08
# 3              A-4  MapQuest  201.0         3 2016-02-08 07:23:34 2016-02-08
# 4              A-5  MapQuest  201.0         2 2016-02-08 07:39:07 2016-02-08
# ...            ...       ...    ...       ...                 ...        ...
# 3513612  A-3513776      Bing    NaN         2 2019-08-23 18:03:25 2019-08-23
# 3513613  A-3513777      Bing    NaN         2 2019-08-23 19:11:30 2019-08-23
# 3513614  A-3513778      Bing    NaN         2 2019-08-23 19:00:21 2019-08-23
# 3513615  A-3513779      Bing    NaN         2 2019-08-23 19:00:21 2019-08-23
# 3513616  A-3513780      Bing    NaN         2 2019-08-23 18:52:06 2019-08-23
#
# ...

# %%
# plotting by week days
order = ['Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']
file_dates.groupby(file_dates['weekday']).size().loc[order].plot.bar()

# %%
file_dates.groupby(file_dates['Civil_Twilight']).size().plot.bar()

# %%
file_dates['YM'] = (file_dates['start_date'].dt.strftime('%Y-%m'))

# %%
file_dates.groupby(file_dates['YM']).size().plot.bar(figsize=(17,5))

# %%
# graph_bar = file.plot.bar(x = '', y = '', rot=0)
